# %% [markdown]
# # Week one homework

# %%
import pandas as pd
from sqlalchemy import create_engine
from time import time

# %%
# pip list

# %%
green = pd.read_csv('green_tripdata_2019-09.csv.gz')
csv_file_path = 'green_tripdata_2019-09.csv'
green.to_csv(csv_file_path, index=Fals

# %%
taxi = pd.read_csv('taxi+_zone_lookup.csv')
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.10         1.0                  N           142
# 1                 0.20         1.0                  N           238
# 2                14.70         1.0                  N           132
# 3                10.60         1.0                  N           138
# 4                 4.94         1.0                  N            68
# ...                ...         ...                ...           ...
# 1369764           8.89         NaN               None           229
# 1369765           7.43         NaN               None            41
# 1369766           6.26         NaN               None            74
# 1369767          19.70         NaN               None           265
# 1369768           4.68         NaN               None            89
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  43             2         8.00   3.00      0.5        0.00
# 1                 151             2         3.00   0.50      0.5        0.00
# 2                 165             1        42.00   0.50      0.5        8.65
# 3                 132             1        29.00   0.50      0.5        6.05
# 4                  33             1        16.50   0.50      0.5        4.06
# ...               ...           ...          ...    ...      ...         ...
# 1369764           181             0        27.78   0.00      0.5        7.46
# 1369765            70             0        32.58   0.00      0.5        0.00
# 1369766           137             0        16.85   0.00      0.5        3.90
# 1369767           188             0        53.68   0.00      0.5        0.00
# 1369768            61             0        25.45   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         11.80
# 1                0.00                    0.3          4.30
# 2                0.00                    0.3         51.95
# 3                0.00                    0.3         36.35
# 4                0.00                    0.3         24.36
# ...               ...                    ...           ...
# 1369764          0.00                    0.3         38.54
# 1369765          6.12                    0.3         39.50
# 1369766          0.00                    0.3         24.05
# 1369767          0.00                    0.3         54.48
# 1369768          0.00                    0.3         29.00
#
#          congestion_surcharge  airport_fee
# 0                         2.5          NaN
# 1                         0.0          NaN
# 2                         0.0          NaN
# 3                         0.0          NaN
# 4                         2.5          NaN
# ...                       ...          ...
# 1369764                   NaN          NaN
# 1369765                   NaN          NaN
# 1369766                   NaN          NaN
# 1369767                   NaN          NaN
# 1369768                   NaN          NaN
#
# [1369769 rows x 19 columns]

# %%
taxi.head()

# %%
green.head()

# %%
green.lpep_pickup_datetime = pd.to_datetime(green.lpep_pickup_datetime)
green.lpep_dropoff_datetime = pd.to_datetime(green.lpep_dropoff_datetime)

# %%
green['pickup_date'] = green['lpep_pickup_datetime'].dt.date
green['pickup_time'] = green['lpep_pickup_datetime'].dt.time
green['dropoff_date'] = green['lpep_dropoff_datetime'].dt.date
green['dropoff_time'] = green['lpep_dropoff_datetime'].dt.time

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.1         1.0                  N           142            43
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          8.0    3.0      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3          11.8                   2.5          NaN

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(green, name='green_tripdata_2019-09', con=engine))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
print(pd.io.sql.get_schema(taxi, name='taxi+_zone_lookup', con=engine))
# Out:
# 10000

# %%
green = pd.read_csv('green_tripdata_2019-09.csv.gz')
green.head(n=0).to_sql(name='green_tripdata_2019_09', con=engine, if_exists='replace')
while True:
    try:
        t_start = time()

        green = next(df_iter)

        green.lpep_pickup_datetime = pd.to_datetime(green.lpep_pickup_datetime)
        green.lpep_dropoff_datetime = pd.to_datetime(green.lpep_dropoff_datetime)
        
        
        
        green.to_sql(name='green_tripdata_2019_09', con=engine, if_exists='append')

        t_end = time()
        
    except StopIteration:
        print('Finished inserting all data.')
        break
# Out:
# 1

# %%
import pandas as pd
from time import time

green = pd.read_csv('green_tripdata_2019-09.csv')

# Use if_exists='replace' to create the table if it doesn't exist
green.head(0).to_sql(name='green_tripdata_2019_09', con=engine, if_exists='replace', index=False)

try:
    t_start = time()

    green['lpep_pickup_datetime'] = pd.to_datetime(green['lpep_pickup_datetime'])
    green['lpep_dropoff_datetime'] = pd.to_datetime(green['lpep_dropoff_datetime'])

    
    green.to_sql(name='green_tripdata_2019_09', con=engine, if_exists='append', index=False)

    t_end = time()
    print(f'Inserted the entire dataset, took {t_end - t_start:.3f} seconds')

except Exception as e:
    print(f'Error during data insertion: {str(e)}')

# %%
# Out:
# 0

# %%
# Out:
# Wall time: 2.53 s
# 1000

# %%
# Out:
# Upload another chunk... took 1.837 seconds
# Upload another chunk... took 1.521 seconds
# Upload another chunk... took 1.557 seconds
# Upload another chunk... took 1.940 seconds
# Upload another chunk... took 1.794 seconds
# Upload another chunk... took 1.632 seconds
# Upload another chunk... took 1.501 seconds
# Upload another chunk... took 1.476 seconds
# Upload another chunk... took 1.417 seconds
# Upload another chunk... took 1.426 seconds
# Upload another chunk... took 1.698 seconds
# Upload another chunk... took 1.707 seconds
# Upload another chunk... took 1.401 seconds
# Upload another chunk... took 1.541 seconds
# Upload another chunk... took 1.459 seconds
# Upload another chunk... took 1.459 seconds
# Upload another chunk... took 1.410 seconds
# Upload another chunk... took 1.631 seconds
# Upload another chunk... took 1.616 seconds
# Upload another chunk... took 1.582 seconds
# Upload another chunk... took 1.417 seconds
# Upload another chunk... took 1.573 seconds
# Upload another chunk... took 1.409 seconds
# Upload another chunk... took 1.360 seconds
# Upload another chunk... took 1.393 seconds
# Upload another chunk... took 1.640 seconds
# Upload another chunk... took 1.501 seconds
# Upload another chunk... took 1.426 seconds
# Upload another chunk... took 1.895 seconds
# Upload another chunk... took 1.789 seconds
# Upload another chunk... took 2.051 seconds
# Upload another chunk... took 2.130 seconds
# Upload another chunk... took 1.925 seconds
# Upload another chunk... took 1.961 seconds
# Upload another chunk... took 1.880 seconds
# Upload another chunk... took 2.292 seconds
# Upload another chunk... took 1.986 seconds
# Upload another chunk... took 2.134 seconds
# Upload another chunk... took 1.764 seconds
# Upload another chunk... took 1.916 seconds
# Upload another chunk... took 1.916 seconds
# Upload another chunk... took 2.103 seconds
# Upload another chunk... took 2.010 seconds
# Upload another chunk... took 1.855 seconds
# Upload another chunk... took 1.846 seconds
# Upload another chunk... took 2.019 seconds
# Upload another chunk... took 2.439 seconds
# Upload another chunk... took 1.987 seconds
# Upload another chunk... took 1.764 seconds
# Upload another chunk... took 1.781 seconds
# Upload another chunk... took 2.085 seconds
# Upload another chunk... took 2.382 seconds
# Upload another chunk... took 2.036 seconds
# Upload another chunk... took 1.978 seconds
# Upload another chunk... took 1.886 seconds
# Upload another chunk... took 1.937 seconds
# Upload another chunk... took 2.085 seconds
# Upload another chunk... took 2.019 seconds
# Upload another chunk... took 1.800 seconds
# Upload another chunk... took 1.653 seconds
# Upload another chunk... took 1.599 seconds
# Upload another chunk... took 1.574 seconds
# Upload another chunk... took 1.499 seconds
# Upload another chunk... took 1.418 seconds
# Upload another chunk... took 1.418 seconds
# Upload another chunk... took 1.625 seconds
# Upload another chunk... took 1.425 seconds
# Upload another chunk... took 1.564 seconds
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18736\1780572307.py in <cell line: 2>()
#       3
#       4     # Check if there are more DataFrames in the iterator
# ----> 5     df1 = next(df_iter)
#       6
#       7     df1["tpep_pickup_datetime"] = pd.to_datetime(df1["tpep_pickup_datetime"])
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __next__(self)
#    1666     def __next__(self) -> DataFrame:
#    1667         try:
# -> 1668             return self.get_chunk()
#    1669         except StopIteration:
#    1670             self.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in get_chunk(self, size)
#    1775                 raise StopIteration
#    1776             size = min(size, self.nrows - self._currow)
# -> 1777         return self.read(nrows=size)
#    1778
#    1779     def __enter__(self) -> TextFileReader:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1746                     columns,
#    1747                     col_dict,
# -> 1748                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1749                     nrows
#    1750                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
